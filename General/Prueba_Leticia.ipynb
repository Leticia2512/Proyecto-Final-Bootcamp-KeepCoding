# %%
from sklearn.model_selection import train_test_split
from eye_pytorch_dataset import EyeDataset
import numpy as np
from torchvision import transforms
from torch.utils.data import Subset
import torch


def create_split(
        parquet_file="Data/parquet/dataset_meta_ojouni.parquet",
        image_dir="224x224",
        feature_cols=["Patient Age", "Patient_Sex_Binario"]):

    ds = EyeDataset(parquet_path=parquet_file,
                    image_dir=image_dir, feature_cols=feature_cols)

    # --- 1) índices y etiquetas (single-label) ---
    idxs = np.arange(len(ds))
    y = np.array(ds.targets)            # vector con cod_target (0..K-1)

    # --- 2) split train (80%) vs temp (20%) estratificado ---
    tr_idx, tmp_idx = train_test_split(
        idxs,
        test_size=0.2,
        random_state=42,
        shuffle=True,
        stratify=y
    )

    # --- 3) split temp en val (10%) vs test (10%) estratificado ---
    va_idx, te_idx = train_test_split(
        tmp_idx,
        test_size=0.5,
        random_state=42,
        shuffle=True,
        stratify=y[tmp_idx]
    )

    train_imgs_transforms = transforms.Compose([
                                                transforms.RandomHorizontalFlip(p= 0.2),
                                                transforms.RandomRotation(15)
                                                ])
    
    dataset_train = Subset(ds, tr_idx)
    dataset_train.transform = train_imgs_transforms

    dataset_val = Subset(ds, va_idx)
    dataset_test = Subset(ds, te_idx)


    torch.save({
    "dataset": ds,          # tu EyeDataset
    "indices": dataset_train    # lista de índices
}, "Data/dataset/train_dataset.pt")

    torch.save({
        "dataset": ds,          # tu EyeDataset
        "indices": dataset_val    # lista de índices
    }, "Data/dataset/val_dataset.pt")

    torch.save({
        "dataset": ds,          # tu EyeDataset
        "indices": dataset_test    # lista de índices
    }, "Data/dataset/test_dataset.pt")


def main():

    create_split()


if __name__ == "__main__":
    
    main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 75
#      70     create_split()
#      73 if __name__ == "__main__":
# ---> 75     main()
#
# Cell In[5], line 70, in main()
#      68 def main():
# ---> 70     create_split()
#
# Cell In[5], line 52, in create_split(parquet_file, image_dir, feature_cols)
#      48     dataset_val = Subset(ds, va_idx)
#      49     dataset_test = Subset(ds, te_idx)
# ---> 52     torch.save({
#      53     "dataset": ds,          # tu EyeDataset
#      54     "indices": dataset_train    # lista de índices
#      55 }, "Data/dataset/train_dataset.pt")
#      57     torch.save({
#      58         "dataset": ds,          # tu EyeDataset
#      59         "indices": dataset_val    # lista de índices
#      60     }, "Data/dataset/val_dataset.pt")
#      62     torch.save({
#      63         "dataset": ds,          # tu EyeDataset
#      64         "indices": dataset_test    # lista de índices
#      65     }, "Data/dataset/test_dataset.pt")
#
# File /opt/anaconda3/envs/retina/lib/python3.10/site-packages/torch/serialization.py:422, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     419 _check_dill_version(pickle_module)
#     421 if _use_new_zipfile_serialization:
# --> 422     with _open_zipfile_writer(f) as opened_zipfile:
#     423         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     424         return
#
# File /opt/anaconda3/envs/retina/lib/python3.10/site-packages/torch/serialization.py:309, in _open_zipfile_writer(name_or_buffer)
#     307 else:
#     308     container = _open_zipfile_writer_buffer
# --> 309 return container(name_or_buffer)
#
# File /opt/anaconda3/envs/retina/lib/python3.10/site-packages/torch/serialization.py:287, in _open_zipfile_writer_file.__init__(self, name)
#     286 def __init__(self, name) -> None:
# --> 287     super(_open_zipfile_writer_file, self).__init__(torch._C.PyTorchFileWriter(str(name)))
#
# RuntimeError: Parent directory Data/dataset does not exist.
